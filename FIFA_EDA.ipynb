# %% [markdown]
# <a href="https://colab.research.google.com/github/shobanjatoth/shobanjatoth/blob/main/FIFA_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
matches=pd.read_excel('matches_1930_2022.xlsx')

# %%
fifa=pd.read_excel("fifa_ranking_2022-10-06.xlsx")
world=pd.read_excel("world_cup.xlsx")

# %%
matches.head()
# Out:
#    home_team  ...                            away_substitute_in_long
# 0  Argentina  ...  ['41&rsquor;|2:0|Randal Kolo Muani|for Ousmane...
# 1    Croatia  ...  ['46&rsquor;|2:1|Ilias Chair|for Abdelhamid Sa...
# 2     France  ...  ['21&rsquor;|1:0|Selim Amallah|for Romain Saïs...
# 3  Argentina  ...  ['46&rsquor;|2:0|Mislav Oršić|for Borna Sosa',...
# 4    Morocco  ...  ['51&rsquor;|1:0|João Cancelo|for Raphaël Guer...
#
# [5 rows x 44 columns]

# %%
fifa.head()
# Out:
#         team team_code association  rank  previous_rank   points  previous_points
# 0     Brazil       BRA    CONMEBOL     1              1  1841.30          1837.56
# 1    Belgium       BEL        UEFA     2              2  1816.71          1821.92
# 2  Argentina       ARG    CONMEBOL     3              3  1773.88          1770.65
# 3     France       FRA        UEFA     4              4  1759.78          1764.85
# 4    England       ENG        UEFA     5              5  1728.47          1737.46

# %%
world.head()
# Out:
#    Year          Host  Teams  ... Attendance AttendanceAvg Matches
# 0  2022         Qatar     32  ...    3404252         53191      64
# 1  2018        Russia     32  ...    3031768         47371      64
# 2  2014        Brazil     32  ...    3429873         53592      64
# 3  2010  South Africa     32  ...    3178856         49670      64
# 4  2006       Germany     32  ...    3352605         52384      64
#
# [5 rows x 9 columns]
